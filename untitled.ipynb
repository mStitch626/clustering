# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.loads import load_csv_dataset, fit_transform, visualize, evaluate_kmeans, kmeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
inscur3 = load_csv_dataset('./dataset/insur_3_new.csv',['MARQUE','USAGE','PROF','PUISS','GARAGE','CONT','GOOD_BAD'], take = None, na_values="?")
inscur3.head()
# Out:
#     MARQUE          USAGE           PROF  PUISS  GARAGE    CONT  GOOD_BAD
# 0  RENAULT  Professionnel        Artisan    6.0    5633   326.0         0
# 1  RENAULT          Prive        Salarie    4.0   62119   499.0         0
# 2  PEUGEOT        Trajets  Fonctionnaire    5.0   62119  1284.0         0
# 3      BMW        Trajets  Fonctionnaire   10.0   14118   835.0         0
# 4  CITROEN  Professionnel    Agriculteur    2.0   71522  1919.0         0

# %%
inscur3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21599 entries, 0 to 21598
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MARQUE    21599 non-null  object
#  1   USAGE     21579 non-null  object
#  2   PROF      21580 non-null  object
#  3   PUISS     21598 non-null  float64
#  4   GARAGE    21599 non-null  int64
#  5   CONT      21598 non-null  float64
#  6   GOOD_BAD  21599 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
inscur3.describe()
# Out:
#               PUISS        GARAGE          CONT      GOOD_BAD
# count  21598.000000  21599.000000  21598.000000  21599.000000
# mean       6.412446  49190.250845   1080.449393      0.264827
# std        2.483934  26027.447248    623.552712      0.441251
# min        1.000000      0.000000      1.000000      0.000000
# 25%        5.000000  28223.000000    540.250000      0.000000
# 50%        6.000000  51649.000000   1080.000000      0.000000
# 75%        8.000000  69282.000000   1620.000000      1.000000
# max       50.000000  95598.000000   2160.000000      1.000000

# %%
inscur3.dropna(subset=['PUISS', 'CONT'], inplace=True)

# %%
inscur3['PROF'].fillna(inscur3['PROF'].mode()[0], inplace=True)
inscur3['USAGE'].fillna(inscur3['USAGE'].mode()[0], inplace=True)
inscur3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21597 entries, 0 to 21598
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MARQUE    21597 non-null  object
#  1   USAGE     21597 non-null  object
#  2   PROF      21597 non-null  object
#  3   PUISS     21597 non-null  float64
#  4   GARAGE    21597 non-null  int64
#  5   CONT      21597 non-null  float64
#  6   GOOD_BAD  21597 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.3+ MB

# %%
inscur3.describe()
# Out:
#               PUISS        GARAGE          CONT      GOOD_BAD
# count  21597.000000  21597.000000  21597.000000  21597.000000
# mean       6.412372  49190.341946   1080.424411      0.264852
# std        2.483968  26027.438286    623.556339      0.441264
# min        1.000000      0.000000      1.000000      0.000000
# 25%        5.000000  28223.000000    540.000000      0.000000
# 50%        6.000000  51649.000000   1080.000000      0.000000
# 75%        8.000000  69282.000000   1620.000000      1.000000
# max       50.000000  95598.000000   2160.000000      1.000000

# %%
scaler = StandardScaler()
num_cols = inscur3.select_dtypes(include=['number']).columns
inscur3[num_cols] = fit_transform(scaler,inscur3[num_cols])

# %%
random_rows = inscur3.sample(n=1000)

# %%
df = pd.DataFrame(random_rows[['PUISS','GARAGE']])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 8770 to 5520
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PUISS   1000 non-null   float64
#  1   GARAGE  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 23.4 KB

# %%
df.to_numpy().shape
# Out:
# (1000, 2)

# %%
#Applying our function
data = df.to_numpy()
label = kmeans(data,10,1000)
# Out:
# distances.shape :  (1000, 10) [1.89140501 0.40826258 2.92909214 2.05165407 1.27315886 0.73105314
#  1.61366992 2.22769121 2.67565743 1.34534218]
# points.shape :  (1000,) [1 5 7]
# [-0.59977662  0.23474332] [False False False False False False False False False False False  True
#  False False False False False False  True False False False False False
#   True False False  True  True  True False False False False  True False
#   True False False  True False False False False False False False False
#  False False False  True False False False False False False False False
#   True False False False False False False False False False False False
#  False False  True False False False False False False False False  True
#  False False False False False False  True  True False False False  True
#  False False False False False False False  True  True False False False
#  False False  True False False False  True False False  True False False
# ...

# %%
# Create a color map using a colormap from matplotlib (e.g., 'viridis')
colors = plt.cm.get_cmap("viridis", len(u_labels))

plt.figure(figsize=(10, 8))
for i in u_labels:
    # Select all data points that belong to cluster 'i'
    cluster_data = data[label == i]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1],
                label=f'Cluster {i}', s=50, edgecolor='k')

plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("KMeans Clustering Visualization")
plt.legend()
plt.show()

# %%
visualize(random_rows[['PUISS','GARAGE']], kmeans, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 visualize(random_rows[['PUISS','GARAGE']], kmeans, 3)
#
# NameError: name 'kmeans' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_blobs

# Generate sample data with 3 clusters
X, _ = make_blobs(n_samples=30000, centers=30, random_state=42)

# Apply K-Means clustering
kmeans = KMeans(n_clusters=30, random_state=42, n_init=10)
labels = kmeans.fit_predict(X)

# Calculate the Silhouette Score
silhouette_avg = silhouette_score(X, labels)
print(f"Silhouette Score: {silhouette_avg:.4f}")

# Plot clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolors='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
            s=200, c='red', marker='X', label='Centroids')
plt.title("K-Means Clustering with 3 Clusters")
plt.legend()
plt.show()
# Out:
# Silhouette Score: 0.3697

# %% [markdown]
# # Old code

# %%
import pandas as pd
from scipy.spatial import distance
from sklearn.preprocessing import StandardScaler

# from scipy.io import arff

# %%
df = pd.read_csv("kdd_data/KDDTrain+.txt", header=None)
columns = (['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent','hot'
,'num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root','num_file_creations'
,'num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','count','srv_count','serror_rate'
,'srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count','dst_host_srv_count'
,'dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate'
,'dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate','outcome','level'])
df.columns = columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df = pd.read_csv("kdd_data/KDDTrain+.txt", header=None)
#       2 columns = (['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent','hot'
#       3 ,'num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root','num_file_creations'
#       4 ,'num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','count','srv_count','serror_rate'
#       5 ,'srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count','dst_host_srv_count'
#       6 ,'dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  object
#  2   service                      125973 non-null  object
#  3   flag                         125973 non-null  object
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
# ...

# %%
df.describe()
# Out:
#            duration     src_bytes     dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086
# min         0.00000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.022687       0.000111       0.204409           0.001222
# std          0.253530       0.014366       2.149968           0.045239
# min          0.000000       0.000000       0.000000           0.000000
# ...

# %%
# dtypes
scaler = StandardScaler()
numeric_cols = ['duration','src_bytes','dst_bytes','land','wrong_fragment','urgent','hot'
,'num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root','num_file_creations'
,'num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','count','srv_count','serror_rate'
,'srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count','dst_host_srv_count'
,'dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate'
,'dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate','level']

# %%
# import pandas as pd
# from sklearn.cluster import KMeans
# from sklearn.preprocessing import LabelEncoder, StandardScaler
# import matplotlib.pyplot as plt

# # Load dataset
# df = pd.read_csv("kdd_data/KDDTrain+.txt", header=None)

# # Define column names
# columns = ['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent','hot',
#            'num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root','num_file_creations',
#            'num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','count','srv_count','serror_rate',
#            'srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count',
#            'dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate','dst_host_srv_diff_host_rate',
#            'dst_host_serror_rate','dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate','outcome','level']
# df.columns = columns

# # Drop categorical columns
# categorical_cols = ['protocol_type', 'service', 'flag', 'outcome']
# df = df.drop(columns=categorical_cols)

# # Normalize numerical features
# scaler = StandardScaler()
# df_scaled = scaler.fit_transform(df)

# # Find optimal number of clusters using the Elbow Method
# inertia = []
# for k in range(1, 11):
#     kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
#     kmeans.fit(df_scaled)
#     inertia.append(kmeans.inertia_)

# # Plot Elbow Method
# plt.figure(figsize=(8, 5))
# plt.plot(K_range, inertia, marker='o', linestyle='--')
# plt.xlabel('Number of Clusters')
# plt.ylabel('Inertia')
# plt.title('Elbow Method for Optimal k')
# plt.show()

# # Apply K-Means clustering with optimal k (let's assume k=5 from the elbow method)
# kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
# df['cluster'] = kmeans.fit_predict(df_scaled)

# # Show cluster assignments
# print(df[['cluster']].value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [59], in <cell line: 28>()
#      28 for k in range(1, 11):
#      29     kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
# ---> 30     kmeans.fit(df_scaled)
#      31     inertia.append(kmeans.inertia_)
#      33 # Plot Elbow Method
#
# File c:\Users\ait7m\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1186, in KMeans.fit(self, X, y, sample_weight)
#    1183     print("Initialization complete")
#    1185 # run a k-means once
# -> 1186 labels, inertia, centers, n_iter_ = kmeans_single(
#    1187     X,
#    1188     sample_weight,
#    1189     centers_init,
#    1190     max_iter=self.max_iter,
#    1191     verbose=self.verbose,
#    1192     tol=self._tol,
#    1193     x_squared_norms=x_squared_norms,
#    1194     n_threads=self._n_threads,
#    1195 )
# ...

# %%
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
